# %%
import numpy as np
from numpy.random import randn
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
from matplotlib import rcParams
# 4_2b

# %% [markdown]
# Creating a line chart from a list objects.

# %%
x = range(1, 10)
y = [1, 2, 3, 4, 0, 4, 3, 2, 1]
plt.plot(x, y)

# %%
x = range(1, 10)
y = [1, 2, 3, 4, 0, 4, 3, 2, 1]
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x77e21a1afcb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x77e21a1ec200>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x77e21a1af590>],
#  'medians': [<matplotlib.lines.Line2D at 0x77e21a1ec800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x77e21a1ecb30>],
#  'means': []}

# %%
x = range(1, 10)
y = [1, 2, 3, 4, 0, 4, 3, 2, 1]
plt.hist(y)
# Out:
# (array([1., 0., 2., 0., 0., 2., 0., 2., 0., 2.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
x = range(1, 10)
y = [1, 2, 3, 4, 0, 4, 3, 2, 1]
plt.scatter(x, y)
